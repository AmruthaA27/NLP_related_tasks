# %% [markdown]
# <a href="https://colab.research.google.com/github/AmruthaA27/NLP_related_tasks/blob/main/Task_8_LangTranslation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import googletrans
import pandas as pd
import numpy as np
# !pip install translate

# %%
df_data = pd.read_csv('English.csv')
Eng_list = df_data["English words/sentences"].tolist()
arr = df_data["English words/sentences"].to_numpy()
np.unique(arr)
print(arr)
print(len(arr))
Spanish_list = []
German_list = []
French_list = []
# Out:
# ['Hi.' 'Run!' 'Run!' ...
#  "Death is something that we're often discouraged to talk about or even think about, but I've realized that preparing for death is one of the most empowering things you can do. Thinking about death clarifies your life."
#  'Since there are usually multiple websites on any given topic, I usually just click the back button when I arrive on any webpage that has pop-up advertising. I just go to the next page found by Google and hope for something less irritating.'
#  "If someone who doesn't know your background says that you sound like a native speaker, it means they probably noticed something about your speaking that made them realize you weren't a native speaker. In other words, you don't really sound like a native speaker."]
# 175621

# %%
#Transalting to Spanish
from translate import Translator
translator= Translator(to_lang="Spanish")
#for i in range(0,10):
for i in range(0,100): 
    translation = translator.translate(Eng_list[i])
    Spanish_list.append(translation)
#df_data["Spanish words/sentences"] = Spanish_list
#df_data.head(10)
print(Spanish_list)
# Out:
# ['Hola.', '¡Corre!', '¡Corre!', '¿Quién?', '-¡Guao!', '¡Fuego!', '¡Socorro!', 'Salta.', '¡Paren!', '¡Paren!', '¡Paren!', '¡Espera!', '¡Espera!', 'Dale.', 'Dale.', 'Dale.', '¡Hola!', '¡Hola!', 'Ya veo.', 'y no me rindo.', '¡He ganado!', '¡He ganado!', 'Lo gané.', '¡Oh, no!', 'Ataca', 'Ataca', '¡Salud!', '¡Salud!', '¡Salud!', '¡Salud!', 'Levántate,', 'Vete ya.', 'Vete ya.', 'Vete ya.', '¡Entendido!', '¡Entendido!', '¿Entendido?', '¿Entendido?', '¿Entendido?', 'Sube en el coche.', 'Sube en el coche.', 'Abrázame', 'Abrázame', 'un ustante', 'un ustante', 'Lo sé.', 'Me fui.', 'Me fui.', 'Mentí.', 'Yo lo manejo.', 'Pagué', 'Tengo 19.', 'Estoy bien.', 'Estoy bien.', 'Escucha.', '¡Ni hablar!', '¡Ni hablar!', '¡Ni hablar!', '¡Ni hablar!', '¡Ni hablar!', '¡Ni hablar!', '¡Ni hablar!', '¡Ni hablar!', '¡Ni hablar!', '¿De verdad?', '¿De verdad?', '¿De verdad?', 'Gracias.', 'Lo intentamos.', 'No sabes nada.', 'No sabes nada.', 'No sabes nada.', 'No sabes nada.', 'Pregúntale a Tom.', '¡Estupendo!', '
# ...

# %%
#Transalting to German
from translate import Translator
translator= Translator(to_lang="German")
#for i in range(0,10):
for i in range(0,100): 
    translation = translator.translate(Eng_list[i])
    German_list.append(translation)
#df_data["Spanish words/sentences"] = Spanish_list
#df_data.head(10)
print(German_list)
# Out:
# ['MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  16 HOURS 44 MINUTES 22 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE', 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  16 HOURS 44 MINUTES 21 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE', 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  16 HOURS 44 MINUTES 21 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE', 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  16 HOURS 44 MINUTES 21 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE', 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  16 HOURS 44 MINUTES 21 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE', 'M
# ...

# %%
#Transalting to French
from translate import Translator
translator= Translator(to_lang="French")
#for i in range(0,10):
for i in range(0,100): 
    translation = translator.translate(Eng_list[i])
    French_list.append(translation)
#df_data["Spanish words/sentences"] = Spanish_list
#df_data.head(10)
print(French_list)
